# %% [markdown]
# # Logistic Regression

# %% [markdown]
# * Logistic Regressonn produces results in a binary format which is used to predict the outcome of a categorical dependent variabel .So the outcome should be descrete/categorical such as : 0 or 1 , Yes or No , True or False , High or Low .

# %% [markdown]
# __Why not Linear Regression :__
#
# * Since our values of Y will be between 0 and 1 , the linear line has to be clipped at 0 and 1 .
#
# * If our data has outliers then we can the linear regression best fit line will change and will not give us acccurate results for out two categories .
#
# ![unnamed.png](attachment:unnamed.png)

# %% [markdown]
# * In logistic regression all the positive points are denoted as +1 and all the negetive points are denoted as -1 .
#
# * Here the intercept is passing through the origin so we make it as zero .
#
# ![Annotation%202020-11-12%201351.jpg](attachment:Annotation%202020-11-12%201351.jpg)
#
# ![WhatsApp%20Image%202020-11-12%20at%207.25.11%20PM.jpeg](attachment:WhatsApp%20Image%202020-11-12%20at%207.25.11%20PM.jpeg)

# %% [markdown]
# __What happen if we have a outlier in our data :__
#
# ![Annotation%202020-11-12%20135.jpg](attachment:Annotation%202020-11-12%20135.jpg)
#
# * In order to get ride of this issue we will use sigmoid function .

# %% [markdown]
# __Sigmoid Function :__
#
# * It will transform the above multiplication between 0 to 1 .
# * It will remove the affect of outlier

# %% [markdown]
# ![main-qimg-6b67bea3311c3429bfb34b6b1737fe0c.jfif](attachment:main-qimg-6b67bea3311c3429bfb34b6b1737fe0c.jfif)

# %% [markdown]
# __One V Rest or One V All :__
#
# * Solving multiclass classification problem with the help of Logistic regression .
#
# ![one-vs-all.png](attachment:one-vs-all.png)

# %% [markdown]
# * In the above case we have 3 output categories , in one iteration we will consider triange as +ve category and other two as -ve category , In the next iteration we will consider square as +ve category and other two as -ve category and same for cross .
#
# * Then record those models outputs as m1 , m2 and m3
#
# ![Annotation%202020-11-12%2013.jpg](attachment:Annotation%202020-11-12%2013.jpg)

# %% [markdown]
# * When the first model is going to get created it will take all the independent fetures and will take O1 as a output feature based on this it will create a model m1 and in the similar way we will create two more models m2 and m3 with the output o2 and o3 .
#
# * At the time of prediction the model which is giving the highest probability will be considered as the output .
