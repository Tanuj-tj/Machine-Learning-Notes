# %% [markdown]
# * Bayes' Theorem is a way of finding a probability when we know certain other probabilities.
# * It is completely based on conditional probability .
#
# It consists of :
#
#
# 1. Conditional Probability
# 2. Independent Event
# 3. Dependent Event
#
# ![Annotation%202020-11-26%201118.jpg](attachment:Annotation%202020-11-26%201118.jpg)
#
# ![Annotation%202020-11-26%20111.jpg](attachment:Annotation%202020-11-26%20111.jpg)
#
# ![Annotation%202020-11-26%2011.jpg](attachment:Annotation%202020-11-26%2011.jpg)

# %% [markdown]
# # Naive Bayes
#
# Article Link : https://www.geeksforgeeks.org/naive-bayes-classifiers/
#
# Video Link : https://www.youtube.com/watch?v=O2L2Uv9pdDA
